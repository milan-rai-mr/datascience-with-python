# %% [markdown]
# <a href="https://colab.research.google.com/github/milan-rai-mr/datascience-with-python/blob/main/MindRisersDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Built-In Functions in Python

# %%
#type
type(5)
# Out:
# int

# %%
one = 1

# %%
type(one)
# Out:
# int

# %%
type(3.45)
# Out:
# float

# %%
type('12')
# Out:
# str

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
type(4-1j)
# Out:
# complex

# %%
len('hello world')
# Out:
# 11

# %% [markdown]
# Type Conversion

# %%
float(4)
# Out:
# 4.0

# %%
int(2.34)
# Out:
# 2

# %%
str(23)
# Out:
# '23'

# %%
int('23')
# Out:
# 23

# %%
int('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3749/702125894.py in <cell line: 0>()
# ----> 1 int('hi')
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
float('2.435')
# Out:
# 2.435

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-23)
# Out:
# True

# %%
bool(100000)
# Out:
# True

# %%
int('123asd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3749/2177522449.py in <cell line: 0>()
# ----> 1 int('123asd')
#
# ValueError: invalid literal for int() with base 10: '123asd'

# %%
str(12567)
# Out:
# '12567'

# %% [markdown]
# Methods in String

# %% [markdown]
# String Methods

# %% [markdown]
# Find Method --> find the index

# %%
a = "putalisadak"

# %%
a.find('t')
# Out:
# 2

# %%
a.find('s')
# Out:
# 6

# %%
a.find('a')
# Out:
# 3

# %%
a.find('-z')
# Out:
# -1

# %% [markdown]
# Count Method --> find the no of time it is repeated

# %%
a.count('a')
# Out:
# 1

# %%
a.count('p')
# Out:
# 1

# %%
a.count('z')
# Out:
# 0

# %% [markdown]
# Upper Method

# %%
country = "Nepal"

# %%
country.upper()
# Out:
# 'NEPAL'

# %%
a.upper()
# Out:
# 'PUTALISADAK'

# %% [markdown]
# Lower Method

# %%
z = "HELLO NEPAL"

# %%
z.lower()
# Out:
# 'hello nepal'

# %% [markdown]
# Title Method

# %%
z
# Out:
# 'HELLO NEPAL'

# %%
z.title()
# Out:
# 'Hello Nepal'

# %% [markdown]
# Capitalize Method

# %%
z.capitalize()
# Out:
# 'Hello nepal'

# %% [markdown]
# Operations in String and integers

# %%
'don't try to memorize code instead understand logic and practice as much as you can'
# Out:
#   File "/tmp/ipykernel_7693/3806974059.py", line 1
#     'don't try to memorize code instead understand logic and practice as much as you can'
#                                                                                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'don\t try to memorize code instead understand logic and practice as much as you can'
# Out:
# 'don\t try to memorize code instead understand logic and practice as much as you can'

# %%
'don"t try to memorize code instead understand logic and practice as much as you can'
# Out:
# 'don"t try to memorize code instead understand logic and practice as much as you can'

# %%
"don't try to memorize code instead understand logic and practice as much as you can"
# Out:
# "don't try to memorize code instead understand logic and practice as much as you can"

# %%
a = """
we have learnt operations, variable declaration
data type, string, int, float, boolean, complex number
We have seen example of string indexing and slicing
We have also gone through some of string inbult function
"""

# %%
a
# Out:
# '\nwe have learnt operations, variable declaration\ndata type, string, int, float, boolean, complex number\nWe have seen example of string indexing and slicing\nWe have also gone through some of string inbult function\n'

# %%
type(a)
# Out:
# str

# %%
'''
Numbers, Strings, Comments,
Variables, Output,
Arithmetic Operators, Comparison Opertors,
Data Type Conversion, Get User Input,
'''
# Out:
# '\nNumbers, Strings, Comments,\nVariables, Output,\nArithmetic Operators, Comparison Opertors,\nData Type Conversion, Get User Input,\n'

# %%
print(4)
# Out:
# 4

# %%
4
# Out:
# 4

# %%
type(4)
# Out:
# int

# %%
type(print(4))
# Out:
# 4
# NoneType

# %%
print('hello')
# Out:
# hello

# %%
input()
# Out:
# 1234
# '1234'

# %%
name = input('Enter your name: ')
# Out:
# Enter your name: 55

# %%
name
# Out:
# '55'

# %%
type(name)
# Out:
# str

# %%
age = int(input('Enter your age:'))
# Out:
# Enter your age:23

# %%
age
# Out:
# 23

# %%
type(age)
# Out:
# int

# %% [markdown]
# DSA (Data Structures and Algorithm)

# %% [markdown]
# *   A list in Python is like a container where we can store multiple items, such as numbers, words, or other things, all
# *   List is mutable which means we can change the items in a list anytime, like adding new ones, removing some, or replacing them.
# *   List defined using square brackets [], with elements seperated by commas (e.g., my_list = [ 1, 2, 3, "hello"]
# *   List support powerful operations like indexing, slicing, iteration and various methods (e.g., .append(), .sort(), .remove())
# *   Python list can hold mixed data types, including nested lists,making it a versatile tool for handling diverse datasets.

# %%
lst = [1, 3.44, True, 'nepal', 5-6j, False, 3, 5.56, 'hi']

# %%
type(lst)
# Out:
# list

# %%
len(lst)
# Out:
# 9

# %%
print(lst)
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %% [markdown]
# Indexing and Slicing

# %%
lst[0]
# Out:
# 1

# %%
lst[5]
# Out:
# False

# %%
lst [6]
# Out:
# 3

# %%
lst[-1]
# Out:
# 'hi'

# %%
lst[-5]
# Out:
# (5-6j)

# %%
lst[::-1]
# Out:
# ['hi', 5.56, 3, False, (5-6j), 'nepal', True, 3.44, 1]

# %%
lst[2:10:-1]
# Out:
# []

# %%
lst[-1:-9:1]
# Out:
# []

# %%
lst[-1:-9:-2]
# Out:
# ['hi', 3, (5-6j), True]

# %%
lst
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %% [markdown]
# Datat Type of Individual Element

# %%
lst
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %%
type(lst)
# Out:
# list

# %%
type(lst[4])
# Out:
# complex

# %%
type(lst[-9])
# Out:
# int

# %% [markdown]
# Reversing the list

# %%
lst
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %%
lst[::-1] #temporary reverse
# Out:
# ['hi', 5.56, 3, False, (5-6j), 'nepal', True, 3.44, 1]

# %%
lst
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %%
lst.reverse() #premanent reverse

# %%
lst
# Out:
# ['hi', 5.56, 3, False, (5-6j), 'nepal', True, 3.44, 1]

# %%
lst[::-1]
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi']

# %%
lst
# Out:
# ['hi', 5.56, 3, False, (5-6j), 'nepal', True, 3.44, 1]

# %%
lst.reverse()

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello']

# %% [markdown]
# *   l1.reverse(): Modifies the original list by reversing it.
# *   l1[::-1]: Creates and returns a new reversed copy without modifying the original list.

# %% [markdown]
# Mutable

# %% [markdown]
# The append() function in python is used with lists to add a new element at the end of the list.

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello']

# %%
lst.append(4)

# %%
lst
# Out:
# [1, 3.44, True, 'nepal', (5-6j), False, 3, 5.56, 'hi', 4]

# %%
lst.append('hello')

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello']

# %%
lst.append(5.55)

# %% [markdown]
# The extend() function in Python adds each element of an iterable (e.g. list, tuple) to the end of a list.

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55]

# %%
lst.extend(345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7693/665632266.py in <cell line: 0>()
# ----> 1 lst.extend(345)
#
# TypeError: 'int' object is not iterable

# %%
lst.extend('ok')

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k']

# %%
lst.extend('123')

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3']

# %%
lst.extend([1, True, 3.33])

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  True,
#  3.33]

# %% [markdown]
# Difference between append() and extend()
#
#
# *   append(): Adds an element as a single item (even if its a list)
# *   extend(): Adds each element of an iterable (e.g, list) to the list

# %% [markdown]
# The insert() function in Python adds an elements at a specified index in a list without replacing existing elements

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  True,
#  3.33]

# %%
lst.insert(3,'ktm')

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  True,
#  3.33]

# %%
lst.insert(-2, 55)

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True,
#  3.33]

# %% [markdown]
# The pop() function in Python removes and returns an element from a list based on its index

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True,
#  3.33]

# %%
lst.pop()
# Out:
# 3.33

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True]

# %%
lst.pop(-10)
# Out:
# 'hello'

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True]

# %% [markdown]
# The remove() function in Python is used to delete the first occurence of a specified value

# %%
lst
# Out:
# [1,
#  3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True]

# %%
lst.remove(1)

# %%
lst
# Out:
# [3.44,
#  True,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True]

# %%
lst.remove(True)

# %%
lst
# Out:
# [3.44,
#  'ktm',
#  'nepal',
#  (5-6j),
#  False,
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  1,
#  55,
#  True]

# %%
lst.remove(True)

# %%
lst
# Out:
# [3.44,
#  'ktm',
#  'nepal',
#  (5-6j),
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  55,
#  True]

# %%
lst[1] = 'npl'

# %%
lst
# Out:
# [3.44,
#  'npl',
#  'nepal',
#  (5-6j),
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  55,
#  True]

# %% [markdown]
# Difference Between remove() and pop()
#
#
# *   remove(): Deletes a specific value
# *   pop(): Removes an element based on its index (and returns it)

# %% [markdown]
# The sort() function in Python sorts the elements of a list in ascending or descending order

# %%
lst
# Out:
# [3.44,
#  'npl',
#  'nepal',
#  (5-6j),
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  55,
#  True]

# %%
lst.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7693/4027238925.py in <cell line: 0>()
# ----> 1 lst.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
numbers = [4, 24, 12, 34, 22, 1]
numbers
# Out:
# [4, 24, 12, 34, 22, 1]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 4, 12, 22, 24, 34]

# %%
fruits = ['mango', 'apple', 'banana', 'avacado']
fruits
# Out:
# ['mango', 'apple', 'banana', 'avacado']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'avacado', 'banana', 'mango']

# %% [markdown]
# The index() function in Python returns the index of the first occurence of a specified element in a list.

# %%
lst
# Out:
# [3.44,
#  'npl',
#  'nepal',
#  (5-6j),
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  55,
#  True]

# %%
lst.index(3)
# Out:
# 4

# %%
lst.index('k')
# Out:
# 12

# %%
lst.index(True)
# Out:
# 17

# %% [markdown]
# The count() function in Python returns the number of occurences of a specified element in a list

# %%
lst
# Out:
# [3.44,
#  'npl',
#  'nepal',
#  (5-6j),
#  3,
#  5.56,
#  'hi',
#  4,
#  'hi',
#  'hello',
#  5.55,
#  'o',
#  'k',
#  '1',
#  '2',
#  '3',
#  55,
#  True]

# %%
lst.count(1)
# Out:
# 1

# %%
lst.count(3)
# Out:
# 1

# %%
lst.count(False)
# Out:
# 0
