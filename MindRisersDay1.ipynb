# %% [markdown]
# <a href="https://colab.research.google.com/github/milan-rai-mr/datascience-with-python/blob/main/MindRisersDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operators, Operands and Operations

# %% [markdown]
# Ctrl + M + B -> Add New Cell
# Ctrl + M + D -> Delete Cell
# Shift + Enter / Ctrl + Enter -> Run cell

# %% [markdown]
# Arithmetic Operation

# %%
4 * 9
# Out:
# 36

# %%
2 + 3
# Out:
# 5

# %%
10 / 2
# Out:
# 5.0

# %%
2 ** 10
# Out:
# 1024

# %%
14 % 3 #modulor operator
# Out:
# 2

# %%
14 // 3 #floor division
# Out:
# 4

# %% [markdown]
# Comparison Operator

# %%
4 < 10
# Out:
# True

# %%
10 < 2
# Out:
# False

# %%
5 <= 5
# Out:
# True

# %%
4 >= 5
# Out:
# False

# %%
4 == 1
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
3 != 4
# Out:
# True

# %%
3 != 3
# Out:
# False

# %% [markdown]
# Comment
#
# -single line comment
# -multiple line comment

# %%
# this is single line comment

# %%
''' This is
multiple
line
 comment'''
# Out:
# ' This is \nmultiple \nline\n comment'

# %%
""" This is
also
multiple line
comment """
# Out:
# ' This is\nalso \nmultiple line \ncomment '

# %% [markdown]
# Variable--> container
#
# Rules for declaring the variable in python:
#
# - must start with letter or underscore(_)
# - can contain numbers, letters, or _
# - python keywords cant be used
# - case sensitive
# - No spaces allowed(use_instead)

# %% [markdown]
# Assignment Operator

# %%
a = 2

# %%
a
# Out:
# 2

# %%
a1 = 5
a1
# Out:
# 5

# %%
a = 6

# %%
a += 3 # a = a + 3
a
# Out:
# 9

# %%
a -= 3 # a = a - 3
a
# Out:
# 6

# %%
a *= 2 # a = a * 2
a
# Out:
# 24

# %%
a /= 2 # a = a / 2
a
# Out:
# 12.0

# %% [markdown]
# Data types
# - integer
# - string
# - boolean
# - float
# - complex

# %% [markdown]
# Built in function
# - len
# - type
# - print
# - input, etc

# %%
i = 11
type(i)
# Out:
# int

# %%
r = 23.3
type(r)
# Out:
# float

# %%
i + r
# Out:
# 34.3

# %%
w = True
type(w)
# Out:
# bool

# %%
u = False

# %%
type(u)
# Out:
# bool

# %% [markdown]
# True -> 1
# False -> 0

# %%
True + True + True
# Out:
# 3

# %%
True * False
# Out:
# 0

# %%
True / False # 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1391/2917913318.py in <cell line: 0>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
False * False
# Out:
# 0

# %%
type (4)
# Out:
# int

# %%
type ('hello')
# Out:
# str

# %%
type (2.3)
# Out:
# float

# %%
type ([1,2,3,4])
# Out:
# list

# %%
t = True
type(t)
# Out:
# bool

# %%
'hello ' * 3
# Out:
# 'hello hello hello '

# %%
"hello " * 4
# Out:
# 'hello hello hello hello '

# %% [markdown]
# # complex --> a + ib
# # format in python --> a + bj
#
# a = real, b = imag,
#
# eg. 2 + 5j ( 2 = real, 5 = imag )
# real and imag are attributes
#
# conjugate changes '+' to '-' and '-' to '+'
# conjugate is method or function

# %%
r = 4 - 2j

# %%
type(r)
# Out:
# complex

# %%
r
# Out:
# (4-2j)

# %%
s = 3 + 7j

# %%
r + s
# Out:
# (7+5j)

# %%
r.real # attribute
# Out:
# 4.0

# %%
r.imag
# Out:
# -2.0

# %%
r
# Out:
# (4-2j)

# %%
r.conjugate()
# Out:
# (4+2j)

# %%
s.real
# Out:
# 3.0

# %%
s.imag
# Out:
# 7.0

# %%
s.conjugate()
# Out:
# (3-7j)

# %% [markdown]
# #Indexing and Slicing
#
# two types of Indexing
# 1. Positive Indexing
# 2. Negative Indexing

# %%
country = 'Nepal'

# %%
country
# Out:
# 'Nepal'

# %%
country[3]
# Out:
# 'a'

# %%
country[-1]
# Out:
# 'l'

# %%
country[3]
# Out:
# 'a'

# %% [markdown]
# slicing
# var[start:end}

# %%
country = "Nepal"

# %%
country[0:3]
# Out:
# 'Nep'

# %%
country[2:4]
# Out:
# 'pa'

# %%
place = "putalisadak"

# %%
place
# Out:
# 'putalisadak'

# %%
place[1:9]
# Out:
# 'utalisad'

# %%
place[2:8]
# Out:
# 'talisa'

# %%
place[-1:-8]
# Out:
# ''

# %%
place[-8:-1]
# Out:
# 'alisada'

# %%
place[:]
# Out:
# 'putalisadak'

# %%
place[:8]
# Out:
# 'putalisa'

# %%
place[3:]
# Out:
# 'alisadak'

# %%
place[-4:]
# Out:
# 'adak'

# %% [markdown]
# var[start:end:jump]

# %%
place
# Out:
# 'putalisadak'

# %%
place[0::2]
# Out:
# 'ptlsdk'

# %%
place[1::2]
# Out:
# 'uaiaa'

# %%
place[10:1:2]
# Out:
# ''

# %%
len(place)
# Out:
# 11

# %%
place[10:1:-2]
# Out:
# 'kdslt'

# %% [markdown]
# Reverse the string

# %%
place
# Out:
# 'putalisadak'

# %%
place[::-1]
# Out:
# 'kadasilatup'
