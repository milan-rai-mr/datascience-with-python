# %% [markdown]
# <a href="https://colab.research.google.com/github/milan-rai-mr/datascience-with-python/blob/main/Day6(Function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Function

# %%
print('This is my print function.')
# Out:
# This is my print function.

# %%
len('This is my print function.')
# Out:
# 26

# %%
type('This is my print function.')
# Out:
# str

# %%
'''
def function_name():
  code
'''
# Out:
# '\ndef function_name():\n  code\n'

# %%
def test():
# Out:
#   File "/tmp/ipykernel_19178/3861551224.py", line 1
#     def test():
#                ^
# SyntaxError: incomplete input

# %%
def test():
  pass

# %%
t = test()

# %%
t

# %%
print(5)
# Out:
# 5

# %%
print("This is a string")
# Out:
# This is a string

# %%
type(print("print"))
# Out:
# print
# NoneType

# %%
print(5)
# Out:
# 5

# %%
type(print(5))
# Out:
# 5
# NoneType

# %%
def print_function(): #function_definition
    print('first function')

# %%
print_function()
# Out:
# first function

# %%
print_function()
print_function()
print_function()
print_function()
# Out:
# first function
# first function
# first function
# first function

# %%
print_function() + print_function()
# Out:
# first function
# first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19178/4217044813.py in <cell line: 0>()
# ----> 1 print_function() + print_function()
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
return 'nepal'
# Out:
#   File "/tmp/ipykernel_19178/3071519388.py", line 1
#     return 'nepal'
#     ^
# SyntaxError: 'return' outside function

# %%
def test2():
  return 'first nepal'

# %%
test2()
# Out:
# 'first nepal'

# %%
test2() + ' nepal '
# Out:
# 'first nepal nepal '

# %%
test2()
test2()
test2()
test2()
# Out:
# 'first nepal'

# %%
def test3():
  return "nepal",2,22.22,[1,2,3]

# %%
test3()
# Out:
# ('nepal', 2, 22.22, [1, 2, 3])

# %%
type(test3())
# Out:
# tuple

# %%
def test4():
