# %% [markdown]
# <a href="https://colab.research.google.com/github/milan-rai-mr/datascience-with-python/blob/main/working_with_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('test.txt','w') # 'w' means write mode, which allows you to create a new file or overwrite an existing file.

# %%
pwd # print working directory
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/  test.txt

# %% [markdown]
# File handling in Python lets you create, read, write, and delete files on your computer. It uses functions like open(), read(), and write() to work with files in modes such as "r" (read), "w" (write), and "a" (append). Always close the file using close() or use the with statement to manage files automatically and avoid errors.

# %%
ls
# Out:
# sample_data/  test.txt

# %%
len('this is my first file to write the string')
# Out:
# 41

# %%
f.write('this is my first file to write the string')
# Out:
# 41

# %%
f.close()

# %%
f = open('test.txt','w')

# %%
f.write('this is my file. ')
# Out:
# 17

# %%
f.close()

# %%
f = open('test.txt','a') # 'a' means append mode, which allows you to add new content to the end of an existing file without overwriting its current content

# %%
f.write('I love data science. ')
# Out:
# 21

# %%
f.close()

# %%
f = open('test.txt','r')

# %%
f.read()
# Out:
# 'this is my file. I love data science. '

# %%
data = open('test.txt','r')

# %%
data.read()
# Out:
# 'this is my file. I love data science. '

# %%
data.readline() # read the data line by line
# Out:
# ''

# %%
data.seek(0) #put the pointer in 0th position
# Out:
# 0

# %%
data.readline()
# Out:
# 'this is my file. I love data science. '

# %%
data.seek(5)
# Out:
# 5

# %%
data.readline()
# Out:
# 'is my file. I love data science. '

# %%
data1 = open('test.txt','r')

# %%
for i in data1:
  print(i)
# Out:
# this is my file. I love data science.

# %%
import os

# %%
len('this is my file i love to do data and ai stuffs')
# Out:
# 47

# %%
os.path.getsize('test.txt')
# Out:
# 38

# %%
len('this is my file i love to do data and ai stuffs.')
# Out:
# 48

# %%
os.remove('test.txt')

# %%
f = open('test1.txt','w')

# %%
f.write(' i love data science')
# Out:
# 20

# %%
f.close()

# %%
os.rename('test1.txt','new.txt')

# %%
import shutil

# %%
shutil.copy('new.txt','copy_new.txt')
# Out:
# 'copy_new.txt'

# %%
# f = open('new.txt','r')
with open('new.txt','r') as f:
  print(f.read())
# Out:
#  i love data science

# %%
with open('newws.txt','w') as f:
  f.write('i love data science')
  f.close()

# %%
with open('newws.txt','r') as f:
  f.write('i love data science')
  print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipykernel_15335/2369863010.py in <cell line: 0>()
#       1 with open('newws.txt','r') as f:
# ----> 2   f.write('i love data science')
#       3   print(f.read())
#
# UnsupportedOperation: not writable

# %%
with open('file.txt','w') as f:
  f.write('This is a file')
  f.close()
